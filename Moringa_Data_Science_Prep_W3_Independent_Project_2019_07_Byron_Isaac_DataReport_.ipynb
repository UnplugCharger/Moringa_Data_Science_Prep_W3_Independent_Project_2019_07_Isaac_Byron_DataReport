# %% [markdown]
# <a href="https://colab.research.google.com/github/UnplugCharger/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Isaac_Byron_DataReport/blob/master/Moringa_Data_Science_Prep_W3_Independent_Project_2019_07_Byron_Isaac_DataReport_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7f7afd3-9558-401e-a763-3ba05d0823f3" name="files[]" multiple disabled />
#      <output id="result-a7f7afd3-9558-401e-a763-3ba05d0823f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cells_geo_description.xlsx to cells_geo_description.xlsx
# Saving cells_geo.csv to cells_geo.csv
# Saving CDR_description.xlsx to CDR_description.xlsx
# Saving Telcom_dataset.csv to Telcom_dataset.csv
# Saving Telcom_dataset3.csv to Telcom_dataset3.csv
# Saving Telcom_dataset2.csv to Telcom_dataset2.csv

# %%
import datetime
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates

# %%
telcom =  pd.read_csv('Telcom_dataset.csv', delimiter = ',',parse_dates=True)
telcom2 = pd.read_csv('Telcom_dataset2.csv', delimiter = ',',parse_dates=True)
telcom3 = pd.read_csv('Telcom_dataset3.csv', delimiter = ',',parse_dates=True)
CDR_description =   pd.read_excel('CDR_description.xlsx', delimiter = ',',parse_dates=True)
cells_geo =  pd.read_csv('cells_geo.csv', delimiter = ';',parse_dates=True,index)
cells_geo_description = pd.read_excel('cells_geo_description.xlsx',delimiter=',')

# %% [markdown]
# Checking all my data frames

# %%
telcom=telcom.rename(columns={'PRODUTC':'PRODUCT','DATETIME':'DATE_TIME'})
telcom
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %%
telcom2=telcom2.rename(columns={'DW_A_NUMBER':'DW_A_NUMBER_INT','DW_B_NUMBER':'DW_B_NUMBER_INT'})

# %%
telcom2
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1      Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2        sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3      Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4        sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms      0  2012-05-08 00:01:53.0  ...     19e2e  896459aace  b7d00e59e4
# 4997     sms     25  2012-05-08 00:01:53.0  ...     19e2e  7e90b35166  211015b14d
# 4998     sms      0  2012-05-08 00:01:53.0  ...     19e2e  fe70e431df  c7ea989264
# 4999    data      0  2012-05-08 00:01:53.0  ...     OTHER  ffa6759bb2         NaN
# ...

# %%
telcom3=telcom3.rename(columns={'CELLID':'CELL_ID','SIET_ID':'SITE_ID'})
telcom3
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1        sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2      Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3        sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
cells_geo.isnull().sum()
# Out:
# Unnamed: 0       0
# VILLES           0
# STATUS          67
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
CDR_description
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
cells_geo_description
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %% [markdown]
# Check for missing Data in the data frames

# %%
cells_geo.isnull().sum()
# Out:
# Unnamed: 0       0
# VILLES           0
# STATUS          67
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
telcom.isnull().sum()
# Out:
# PRODUCT              0
# VALUE                0
# DATE_TIME            0
# CELL_ON_SITE         0
# DW_A_NUMBER_INT      0
# DW_B_NUMBER_INT      0
# COUNTRY_A            0
# COUNTRY_B            0
# CELL_ID              0
# SITE_ID            716
# dtype: int64

# %%
telcom2.isnull().sum()
# Out:
# PRODUCT           0
# VALUE             0
# DATE_TIME         0
# CELL_ON_SITE      0
# DW_A_NUMBER       0
# DW_B_NUMBER       0
# COUNTRY_A         0
# COUNTRY_B         0
# CELL_ID           0
# SITE_ID         676
# dtype: int64

# %%
telcom3.isnull().sum()
# Out:
# PRODUCT              0
# VALUE                0
# DATE_TIME            0
# CELL_ON_SITE         0
# DW_A_NUMBER_INT      0
# DW_B_NUMBER_INT      0
# COUNTRY_A            0
# COUNTRY_B            0
# CELL_ID              0
# SITE_ID            605
# dtype: int64

# %% [markdown]
# harmonising the colum names in the telecom data frames

# %%
telcom.rename(columns={'PRODUTC':'PRODUCT'})
# Out:
#      PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996     sms    100  2012-05-07 00:01:54.0  ...     OTHER  0c2371d9bc  1e751d08a4
# 4997   Voice      1  2012-05-07 00:01:54.0  ...     19e2e  5fb791cf56  65efe2bc62
# 4998   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  7773627c12  9ef9616350
# 4999   Voice      0  2012-05-07 00:01:54.0  ...     19e2e  3f4af49d6c  969b8d0e39
# ...

# %% [markdown]
# Joining the three Telecomtables

# %%
new_set = pd.concat([telcom,telcom2,telcom3],ignore_index=True,axis=0)

# %%
new_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15003 entries, 0 to 15002
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          15003 non-null  object
#  1   VALUE            15003 non-null  int64
#  2   DATE_TIME        15003 non-null  object
#  3   CELL_ON_SITE     15003 non-null  object
#  4   DW_A_NUMBER_INT  15003 non-null  object
#  5   DW_B_NUMBER_INT  15003 non-null  object
#  6   COUNTRY_A        15003 non-null  object
#  7   COUNTRY_B        15003 non-null  object
#  8   CELL_ID          15003 non-null  object
#  9   SITE_ID          13006 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# filling in the missing data in the telecom combined table

# %%
new_set.isnull().sum()
# Out:
# PRODUCT               0
# VALUE                 0
# DATE_TIME             0
# CELL_ON_SITE          0
# DW_A_NUMBER_INT       0
# DW_B_NUMBER_INT       0
# COUNTRY_A             0
# COUNTRY_B             0
# CELL_ID               0
# SITE_ID            1997
# dtype: int64

# %%
new_set[new_set.SITE_ID.isnull()]
# Out:
#       PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID SITE_ID
# 685      data      0  2012-05-07 00:00:00.0  ...     OTHER  ffa6759bb2     NaN
# 686      data      0  2012-05-07 00:00:00.0  ...     OTHER  ffa6759bb2     NaN
# 687      data      0  2012-05-07 00:00:00.0  ...     OTHER  ffa6759bb2     NaN
# 726      data      0  2012-05-07 00:00:01.0  ...     OTHER  ffa6759bb2     NaN
# 727      data      0  2012-05-07 00:00:01.0  ...     OTHER  ffa6759bb2     NaN
# ...       ...    ...                    ...  ...       ...         ...     ...
# 14958    data      0  2012-05-09 00:01:42.0  ...     OTHER  ffa6759bb2     NaN
# 14959    data      0  2012-05-09 00:01:42.0  ...     OTHER  ffa6759bb2     NaN
# 14960    data      0  2012-05-09 00:01:42.0  ...     OTHER  ffa6759bb2     NaN
# 14961    data      0  2012-05-09 00:01:42.0  ...     OTHER  ffa6759bb2     NaN
# 14962    data      0  2012-05-09 00:01:42.0  ...     OTHER  ffa6759bb2     NaN
#
# ...

# %% [markdown]
# DROPPING ROWS WITH MISSING VALUES FROM THE TWO DATASETS

# %%
new_set = new_set.dropna(how='any')
new_set
# Out:
#       PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0       Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...       ...    ...                    ...  ...       ...         ...         ...
# 14998   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 15001   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
cells_geo= cells_geo.dropna(how='any')
cells_geo
# Out:
#         VILLES      STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 23       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...        ...         ...          ...  ...            ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %% [markdown]
# Dropping Unneeded columns from the new_set data frame and the cells_geo dataframe

# %%
new_set
# Out:
#       PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0       Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...       ...    ...                    ...  ...       ...         ...         ...
# 14998   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 15001   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
h= new_set.drop('CELL_ON_SITE',axis=1,inplace= True)
new_set

# %%
new_set
# Out:
#       PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0       Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...       ...    ...                    ...  ...       ...         ...         ...
# 14998   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 15001   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# ...

# %%
new_set.drop('COUNTRY_B',axis=1,inplace= True)
new_set
# Out:
#       PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0       Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  ...  051KhYDCpv  051KhYDCpv
# ...       ...    ...  ...         ...         ...
# 14998   Voice      0  ...  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  ...  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  ...  a4731e780e  d68260ef50
# 15001   Voice     30  ...  98ed726da2  b4130b54ab
# 15002   Voice     60  ...  1c11a2fcbb  6d70dae094
#
# [13006 rows x 7 columns]

# %%
cells_geo.drop('Unnamed: 0',axis=1,inplace= True)

# %%
cells_geo
# Out:
#         VILLES      STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 23       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  f740406877  0f34c36ac5
# 24       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  959e54c8f7  0f34c36ac5
# 25       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  56b7e7000c  0f34c36ac5
# 26       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  bc51c17a6f  0f34c36ac5
# 27       ABOBO  In Service      ABIDJAN  ...  ABIDJAN NORTH  e460975c9f  0f34c36ac5
# ...        ...         ...          ...  ...            ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...   CENTRE NORTH  d4a6a0b645  61bee9c70c
# ...

# %%
new_set
# Out:
#       PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0       Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  ...  051KhYDCpv  051KhYDCpv
# ...       ...    ...  ...         ...         ...
# 14998   Voice      0  ...  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  ...  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  ...  a4731e780e  d68260ef50
# 15001   Voice     30  ...  98ed726da2  b4130b54ab
# 15002   Voice     60  ...  1c11a2fcbb  6d70dae094
#
# [13006 rows x 7 columns]

# %% [markdown]
# Changing the data type of the date time column from string

# %%
new_set.dtypes
# Out:
# PRODUCT            object
# VALUE               int64
# DATE_TIME          object
# DW_A_NUMBER_INT    object
# DW_B_NUMBER_INT    object
# CELL_ID            object
# SITE_ID            object
# dtype: object

# %%
new_set['DATE_TIME']= pd.to_datetime(new_set['DATE_TIME'])

# %%
new_set.dtypes
# Out:
# PRODUCT                    object
# VALUE                       int64
# DATE_TIME          datetime64[ns]
# DW_A_NUMBER_INT            object
# DW_B_NUMBER_INT            object
# CELL_ID                    object
# SITE_ID                    object
# dtype: object

# %% [markdown]
# At what time were most cells inservice

# %%
# Out:
# DATE_TIME
# 0     28.831983
# 23    18.991580
# Name: VALUE, dtype: float64

# %% [markdown]
# how did value flactuate by hour

# %%
new_set .groupby(new_set.DATE_TIME.dt.hour).VALUE.mean().plot()

# %% [markdown]
# join my two data frames using the common column

# %%
new_set.CELL_ID.unique()
# Out:
# array(['/TJNe+Mmtu', '/+cKZKIp41', '/u0FSD+ahi', ..., 'd5bdd4f4cb',
#        '425d28ede5', '6467daa1db'], dtype=object)

# %%
cells_geo.CELL_ID.unique()
# Out:
# array(['f740406877', '959e54c8f7', '56b7e7000c', ..., 'cb71f8a29c',
#        'd4a6a0b645', 'f9f3e42589'], dtype=object)

# %%
overal_set = pd.merge(new_set,cells_geo,on='CELL_ID')
overal_set
# Out:
# Empty DataFrame
# Columns: [PRODUCT, VALUE, DATE_TIME, DW_A_NUMBER_INT, DW_B_NUMBER_INT, CELL_ID, SITE_ID, VILLES, STATUS, LOCALISATION, DECOUPZONE, ZONENAME, LONGITUDE, LATITUDE, REGION, AREA, SITE_CODE]
# Index: []

# %%
overal_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PRODUCT          0 non-null      object
#  1   VALUE            0 non-null      int64
#  2   DATE_TIME        0 non-null      datetime64[ns]
#  3   DW_A_NUMBER_INT  0 non-null      object
#  4   DW_B_NUMBER_INT  0 non-null      object
#  5   CELL_ID          0 non-null      object
#  6   SITE_ID          0 non-null      object
#  7   VILLES           0 non-null      object
#  8   STATUS           0 non-null      object
#  9   LOCALISATION     0 non-null      object
#  10  DECOUPZONE       0 non-null      object
#  11  ZONENAME         0 non-null      object
#  12  LONGITUDE        0 non-null      float64
#  13  LATITUDE         0 non-null      float64
#  14  REGION           0 non-null      object
#  15  AREA             0 non-null      object
#  16  SITE_CODE        0 non-null      object
# ...

# %%
new_set
# Out:
#       PRODUCT  VALUE  ...     CELL_ID     SITE_ID
# 0       Voice      0  ...  /TJNe+Mmtu  /TJNe+Mmtu
# 1         sms      0  ...  /+cKZKIp41  /+cKZKIp41
# 2         sms     25  ...  /u0FSD+ahi  /u0FSD+ahi
# 3       Voice     56  ...  +cNeJzsTp3  +cNeJzsTp3
# 4       Voice     14  ...  051KhYDCpv  051KhYDCpv
# ...       ...    ...  ...         ...         ...
# 14998   Voice      0  ...  2aa04dcab7  f7d63a29e5
# 14999   Voice     62  ...  7f1f2f889f  b4ddb9e93c
# 15000   Voice     32  ...  a4731e780e  d68260ef50
# 15001   Voice     30  ...  98ed726da2  b4130b54ab
# 15002   Voice     60  ...  1c11a2fcbb  6d70dae094
#
# [13006 rows x 7 columns]

# %%
new_set['PRODUCT'].value_counts()[:].index.tolist()
# Out:
# ['sms', 'Voice', 'data']

# %%
cells_geo['VILLES'].value_counts()[:10].index.tolist()
# Out:
# ['COCODY',
#  'YOPOUGON',
#  'ABOBO',
#  'MARCORY',
#  'TREICHVILLE',
#  'ADJAME',
#  'YAMOUSSOUKRO',
#  'PLATEAU',
#  'KOUMASSI',
#  'BOUAKE']
